# %% [markdown]
# <a href="https://colab.research.google.com/github/JuniorFigueroa18/DSHSRP/blob/main/Data_Science_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/athlete_events.csv (1).zip")
display(df.head())
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# I uploaded and display this dataset to identify the x-axis and y-axis, as well as to analyze how the **data differs for each individual**.

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ,

# %%
display(df.iloc[1])
# Out:
# ID                                   2
# Name                          A Lamusi
# Sex                                  M
# Age                               23.0
# Height                           170.0
# Weight                            60.0
# Team                             China
# NOC                                CHN
# Games                      2012 Summer
# Year                              2012
# Season                          Summer
# City                            London
# Sport                             Judo
# Event     Judo Men's Extra-Lightweight
# Medal                              NaN
# Name: 1, dtype: object

# %%
display(df.iloc[2])
# Out:
# ID                              3
# Name          Gunnar Nielsen Aaby
# Sex                             M
# Age                          24.0
# Height                        NaN
# Weight                        NaN
# Team                      Denmark
# NOC                           DEN
# Games                 1920 Summer
# Year                         1920
# Season                     Summer
# City                    Antwerpen
# Sport                    Football
# Event     Football Men's Football
# Medal                         NaN
# Name: 2, dtype: object

# %%
display(df.iloc[3])
# Out:
# ID                                  4
# Name             Edgar Lindenau Aabye
# Sex                                 M
# Age                              34.0
# Height                            NaN
# Weight                            NaN
# Team                   Denmark/Sweden
# NOC                               DEN
# Games                     1900 Summer
# Year                             1900
# Season                         Summer
# City                            Paris
# Sport                      Tug-Of-War
# Event     Tug-Of-War Men's Tug-Of-War
# Medal                            Gold
# Name: 3, dtype: object

# %%
display(df.iloc[4])
# Out:
# ID                                       5
# Name              Christine Jacoba Aaftink
# Sex                                      F
# Age                                   21.0
# Height                               185.0
# Weight                                82.0
# Team                           Netherlands
# NOC                                    NED
# Games                          1988 Winter
# Year                                  1988
# Season                              Winter
# City                               Calgary
# Sport                        Speed Skating
# Event     Speed Skating Women's 500 metres
# Medal                                  NaN
# Name: 4, dtype: object

# %%
display(df.iloc[5])
# Out:
# ID                                         5
# Name                Christine Jacoba Aaftink
# Sex                                        F
# Age                                     21.0
# Height                                 185.0
# Weight                                  82.0
# Team                             Netherlands
# NOC                                      NED
# Games                            1988 Winter
# Year                                    1988
# Season                                Winter
# City                                 Calgary
# Sport                          Speed Skating
# Event     Speed Skating Women's 1,000 metres
# Medal                                    NaN
# Name: 5, dtype: object

# %%
display(df.iloc[6])
# Out:
# ID                                       5
# Name              Christine Jacoba Aaftink
# Sex                                      F
# Age                                   25.0
# Height                               185.0
# Weight                                82.0
# Team                           Netherlands
# NOC                                    NED
# Games                          1992 Winter
# Year                                  1992
# Season                              Winter
# City                           Albertville
# Sport                        Speed Skating
# Event     Speed Skating Women's 500 metres
# Medal                                  NaN
# Name: 6, dtype: object

# %%
display(df.iloc[7])
# Out:
# ID                                         5
# Name                Christine Jacoba Aaftink
# Sex                                        F
# Age                                     25.0
# Height                                 185.0
# Weight                                  82.0
# Team                             Netherlands
# NOC                                      NED
# Games                            1992 Winter
# Year                                    1992
# Season                                Winter
# City                             Albertville
# Sport                          Speed Skating
# Event     Speed Skating Women's 1,000 metres
# Medal                                    NaN
# Name: 7, dtype: object

# %%
display(df.iloc[8])
# Out:
# ID                                       5
# Name              Christine Jacoba Aaftink
# Sex                                      F
# Age                                   27.0
# Height                               185.0
# Weight                                82.0
# Team                           Netherlands
# NOC                                    NED
# Games                          1994 Winter
# Year                                  1994
# Season                              Winter
# City                           Lillehammer
# Sport                        Speed Skating
# Event     Speed Skating Women's 500 metres
# Medal                                  NaN
# Name: 8, dtype: object

# %%
display(df.iloc[9])
# Out:
# ID                                         5
# Name                Christine Jacoba Aaftink
# Sex                                        F
# Age                                     27.0
# Height                                 185.0
# Weight                                  82.0
# Team                             Netherlands
# NOC                                      NED
# Games                            1994 Winter
# Year                                    1994
# Season                                Winter
# City                             Lillehammer
# Sport                          Speed Skating
# Event     Speed Skating Women's 1,000 metres
# Medal                                    NaN
# Name: 9, dtype: object

# %%
display(df.iloc[10])
# Out:
# ID                                               6
# Name                               Per Knut Aaland
# Sex                                              M
# Age                                           31.0
# Height                                       188.0
# Weight                                        75.0
# Team                                 United States
# NOC                                            USA
# Games                                  1992 Winter
# Year                                          1992
# Season                                      Winter
# City                                   Albertville
# Sport                         Cross Country Skiing
# Event     Cross Country Skiing Men's 10 kilometres
# Medal                                          NaN
# Name: 10, dtype: object

# %%
medals_df = df.dropna(subset=['Medal'])
print(f"Total number of medals won: {len(medals_df)}")
# Out:
# Total number of medals won: 39783

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Height', data=df)
plt.title('Height vs. Age of Participants')
plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# %%
country_medals = medals_df['Team'].value_counts().head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=country_medals.index, y=country_medals.values, hue=country_medals.index, palette='viridis', legend=False)
plt.title('Top 10 Countries by Number of Olympic Medals')
plt.xlabel('Country')
plt.ylabel('Number of Medals')
plt.tight_layout()
plt.show()

# %%
top_countries = country_medals.index.tolist()
top_countries_df = medals_df[medals_df['Team'].isin(top_countries)]

medals_by_season_year_team = top_countries_df.groupby(['Year', 'Season', 'Team']).size().unstack(fill_value=0)
display(medals_by_season_year_team.head(full))
# Out:
# Team         Australia  Canada  France  Germany  Great Britain  Hungary  \
# Year Season
# 1896 Summer          2       0      11       31              7        6
# 1900 Summer          5       2      75        2             22        5
# 1904 Summer          4       2       1       15              2        4
# 1906 Summer          3       2      45       30             31       13
# 1908 Summer          0      37      36       19            167       20
#
# Team         Italy  Soviet Union  Sweden  United States
# Year Season
# 1896 Summer      0             0       0             20
# 1900 Summer      5             0       1             45
# 1904 Summer      0             0       0            199
# 1906 Summer      9             0      21             24
# 1908 Summer      8             0      79             65

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 8))
sns.lineplot(data=medals_by_year_team, dashes=False)
plt.title('Medal Counts of Top 10 Countries Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
